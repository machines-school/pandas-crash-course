# %%
import pandas as pd

# %% [markdown]
# #  Read CSV File

# %%
pwd
# Out:
# '/Users/80094/Workspace/machines-school/pandas-crash-course'

# %%
df = pd.read_csv('./sales-jan-2009.csv')

# %%
df
# Out:
#      Transaction_date   Product  Price Payment_Type               Name  \
# 0    01/02/2009 04:53  Product1   1200         Visa             Betina
# 1    01/02/2009 13:08  Product1   1200   Mastercard  Federica e Andrea
# 2    01/04/2009 12:56  Product2   3600         Visa             Gerd W
# 3    01/04/2009 13:19  Product1   1200         Visa           LAURENCE
# 4    01/04/2009 20:11  Product1   1200   Mastercard              Fleur
# ..                ...       ...    ...          ...                ...
# 993  01/02/2009 17:24  Product2   3600       Diners              clara
# 994  01/04/2009 18:57  Product1   1200   Mastercard               KELI
# 995  01/23/2009 12:42  Product2   3600   Mastercard               Anke
# 996  01/07/2009 19:48  Product2   3600   Mastercard             TRICIA
# 997  01/25/2009 05:57  Product1   1200         Amex             pamela
#
#                City              State        Country  Account_Created  \
# ...

# %%
newdf = df[['City', 'State']]

# %%
newdf
# Out:
#                City              State
# 0         Parkville                 MO
# 1           Astoria                 OR
# 2    Cahaba Heights                 AL
# 3         Mickleton                 NJ
# 4            Peoria                 IL
# ..              ...                ...
# 993           Perth  Western Australia
# 994       Worongary         Queensland
# 995          Avalon    New South Wales
# 996          Sydney    New South Wales
# 997        Ayacucho       Buenos Aires
#
# [998 rows x 2 columns]

# %% [markdown]
# # Save CSV file

# %%
newdf.to_csv('mynew.csv', index=True)

# %% [markdown]
# # Read Excel File
#
# pip or conda to install openpyxl

# %%
df = pd.read_excel('./office-supply-sales.xlsx', sheet_name='Sheet1')

# %%
df
# Out:
#               OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 0   2020-06-01 00:00:00     East     Jones   Pencil     95      1.99   189.05
# 1             1/23/2020  Central    Kivell   Binder     50     19.99   999.50
# 2   2020-09-02 00:00:00  Central   Jardine   Pencil     36      4.99   179.64
# 3             2/26/2020  Central      Gill      Pen     27     19.99   539.73
# 4             3/15/2020     West   Sorvino   Pencil     56      2.99   167.44
# 5   2020-01-04 00:00:00     East     Jones   Binder     60      4.99   299.40
# 6             4/18/2020  Central   Andrews   Pencil     75      1.99   149.25
# 7   2020-05-05 00:00:00  Central   Jardine   Pencil     90      4.99   449.10
# 8             5/22/2020     West  Thompson   Pencil     32      1.99    63.68
# 9   2020-08-06 00:00:00     East     Jones   Binder     60      8.99   539.40
# 10            6/25/2020  Central    Morgan   Pencil     90      4.99   449.10
# ...

# %%
newdf = df[['Region', 'Total']]

# %%
newdf
# Out:
#      Region    Total
# 0      East   189.05
# 1   Central   999.50
# 2   Central   179.64
# 3   Central   539.73
# 4      West   167.44
# 5      East   299.40
# 6   Central   149.25
# 7   Central   449.10
# 8      West    63.68
# 9      East   539.40
# 10  Central   449.10
# 11     East    57.71
# 12     East  1619.19
# 13     East   174.65
# 14  Central   250.00
# 15     East   255.84
# 16  Central   251.72
# 17     East   575.36
# 18     East   299.85
# 19  Central   479.04
# 20  Central    86.43
# 21     East  1183.26
# 22  Central   413.54
# 23  Central  1305.00
# 24     East    19.96
# 25     West   139.93
# 26  Central   249.50
# 27  Central   131.34
# 28     East   479.04
# 29  Central    68.37
# 30  Central   719.20
# 31  Central   625.00
# 32     East   309.38
# 33  Central   686.95
# 34  Central  1005.90
# 35     West   825.00
# 36  Central     9.03
# 37     West   151.24
# 38     West  1139.43
# 39  Central    18.06
# 40  Central    54.89
# 41  Central  1879.06
# ...

# %%
newdf.to_excel('mynew.xlsx', sheet_name='Sheet1', index=False)
